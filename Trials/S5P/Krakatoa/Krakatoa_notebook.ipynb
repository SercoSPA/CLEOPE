# %% [markdown]
# # Copernicus Sentinels catch emissions of Krakatoa volcanic eruption
#
# Dormeant since 2018, the Anak Krakatoa volcano, located in the Sonda strait between Sumatra and Java islands in Indonesia, recently awoke. Copernicus Sentinels, our eyes on Earth, can give important information on its aftermath and in this trial notebook we are going to have a look on the ejected plumes.

# %%
import os, sys
sys.path.append(os.path.join(os.path.expanduser("~"),"CLEOPE/Trials/modules"))
import data_processing_S5P as dp5P
import data_processing_S3_slstr as dpS3
import data_processing_S2_affine as dpS2
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
centre = (105.419167,-6.103611) # coordinates of Krakatoa volcano (green circle)
ymin,ymax,xmin,xmax = (-6.4,-5.0,104.5,106.0) # bounds for S5P images 
bounds = (105.0,-6.2,105.5,-5.8) # bounds for S3 SLSTR and S2 images

# %% [markdown]
# You can choose to work with local files or using the Advanced API. Functions in this tutorial can manage both choices independently and automatically, but only if product of interest are provided (as a list or a file). <br>
# Please note that products used in this example notebook could be *offline*: use the `order` function in the `qm` module to retrieve them first.
# ### Using the Advanced API (ENS)
# The input list must contain the position of products in the remote file system. Note that this list is automatically provided using the `SEARCH.ipynb` trial notebook, aimed at facilitating the data access via ENS. Products are found via ENS at their pseudopath, accessed and processed in situ, without any local download. <br>
# ### Using OData API
# Load a custom list containing the products downloaded in the `local_files` folder. To do that, use the `download` function in the `qm` module, which will download and save items via your own Jupyter Notebook using OData protocol. Check out `DISCOVER_ONDA.ipynb` for more details. <br>
# Downloads are stored in the 📁`local_files` folder. The 📄`list_local.txt` file will be created and updated in this working directory with the new downloaded item, authomatically.

# %% [markdown]
# Please note that this notebook is organised into sections which can be run separately to prevent kernel interruptions due to memory limitation. Refresh kernel at each numbered section and re-load modules. <br>
# 🌟 *Upgrade CLEOPE to increase your own computational resources!*
#
# ## 1. Catch the sulfure dioxide plumes using S5P
#
# SO2 is the main proxy for volcanic ash emissions, revealing fine details regarding the plume disperse in the atmosphere. Transient increasing SO2 concentration indicates that the volcano is actively expelling materials.

# %%
ds = dp5P.read((ymin,ymax,xmin,xmax),"tropomi_remote.txt") # specify the input file list and the coordinates to clip the data set
maps = dp5P.mapping((ymin,ymax,xmin,xmax),ds,"tropomi_remote.txt",plotmap=True,centre=centre) # create maps

# %% [markdown]
# ## 2. Plume cooling detection via SLSTR TOA radiances
#
# The SLSTR instrument is able to detect thick volcanic ash plumes using thermal infrared channels. Here we chose SLSTR S9 band nadir view to detect plume top temperature, appearing cooler than the rest of the map, due to the effect shown in the second stage of the figure below.
#
# <img src="../../media/volcano_plume.jpg" alt="drawing" width="500" height="300"/>

# %%
geometry,bands = dpS3.open_files("slstr_remote.txt") 
ds = dpS3.datasets(geometry,bands) # read and clip the data sets
M = dpS3.distribution(bounds,ds)  
xmesh,ymesh,di = dpS3.interp_map(M,bounds) # create a map

# %%
fig = dpS3.image(xmesh,ymesh,di,ds,centre=centre)

# %% [markdown]
# ## 3. True color equalized RGB stack
#
# Plume shape in the temperature map is in agreement with the optic true RGB stack, sensed just ten minutes later.

# %%
p = dpS2.product("s2_remote.txt")
rgb = []
for f in p:
    rgb.append(dpS2.reproject(bands=dpS2.rgb_bands(f))) # affine reprojection of coordinates

# take a clip of the tile over coordinates xmin,xmax,ymin,ymax (the same as SLSTR image)
cli_rgb = dpS2.clip(rgb[0],(105.0,105.5,-6.2,-5.8)) # only one image in this example
del rgb

# %%
img = dpS2.equalize_img(cli_rgb) # color-equalizing function using cv2 Python module

import matplotlib.pyplot as plt
fig,ax = plt.subplots(1,1)
img.plot.imshow(yincrease=False,add_labels=False,ax=ax)
ax.set(title=dpS2.dates(dpS2.product("s2_remote.txt"))[0])
plt.show()
